# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
qpos_targ = np.load("ostrichrl/ostrichrl/assets/mocap/cassie/qpos/0001.npy")
qvel_targ = np.load("ostrichrl/ostrichrl/assets/mocap/cassie/qvel/0001.npy")
xipos_targ = np.load("ostrichrl/ostrichrl/assets/mocap/cassie/xipos/0001.npy")

# %%
qpos_targ.shape
# Out:
# (390, 32)

# %%
qvel_targ.shape
# Out:
# (390, 32)

# %%
xipos_targ.shape
# Out:
# (390, 24, 3)

# %%
#qpos_targ[:,31]

# %%
plt.plot(qpos_targ[:,2])
